# %%
import pandas as pd
import numpy as np
import altair as alt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
alt.renderers.enable('notebook')
alt.themes.enable('opaque')
# Out:
# ThemeRegistry.enable('opaque')

# %%
depth_8 = pd.read_csv('data/depth_8.csv')
depth_9 = pd.read_csv('data/depth_9.csv')
depth_10 = pd.read_csv('data/depth_10.csv')
depth_11 = pd.read_csv('data/depth_11.csv')
depth_12 = pd.read_csv('data/depth_12.csv')
depth_13 = pd.read_csv('data/depth_13.csv')

# %%
c1 = alt.Chart(depth_10).mark_line(color='blue', point = True).encode(
    alt.X('iteration:N'),
    alt.Y('training:Q', scale=alt.Scale(zero=False)),
    tooltip = ['training']
)

c2 = alt.Chart(depth_10).mark_line(color='red', point = True).encode(
    alt.X('iteration:N'),
    alt.Y('test:Q', scale=alt.Scale(zero=False)),
    tooltip = ['test']
)

(c1 + c2).interactive()

# %%
c1 = alt.Chart(depth_10).mark_line(color='blue', interpolate='step-after').encode(
    alt.X('iteration:O'),
    alt.Y('test:Q', scale=alt.Scale(zero=False)),
)

c1.interactive()

# %%
c1 = alt.Chart(depth_8).mark_line(color='green', point = True).encode(
    alt.X('iteration:N'),
    alt.Y('training:Q', scale=alt.Scale(zero=False)),
    tooltip = ['training']
)

c2 = alt.Chart(depth_9).mark_line(color='red', point = True).encode(
    alt.X('iteration:N'),
    alt.Y('training:Q', scale=alt.Scale(zero=False)),
    tooltip = ['training']
)

c3 = alt.Chart(depth_10).mark_line(color='blue', point = True).encode(
    alt.X('iteration:N'),
    alt.Y('training:Q', scale=alt.Scale(zero=False)),
    tooltip = ['training']
)

c4 = alt.Chart(depth_11).mark_line(color='orange', point = True).encode(
    alt.X('iteration:N'),
    alt.Y('training:Q', scale=alt.Scale(zero=False)),
    tooltip = ['training']
)

c5 = alt.Chart(depth_12).mark_line(color='black', point = True).encode(
    alt.X('iteration:N'),
    alt.Y('training:Q', scale=alt.Scale(zero=False)),
    tooltip = ['training']
)

c6 = alt.Chart(depth_13).mark_line(color='yellow', point = True).encode(
    alt.X('iteration:N'),
    alt.Y('training:Q', scale=alt.Scale(zero=False)),
    tooltip = ['training']
)

# %%
chart = (c1 + c2 + c3 + c4 + c5 + c6).interactive()
chart.save('plots/overfitting_depth.png', scale_factor = 5.0)

# %%
chart

# %%
c1 = alt.Chart(depth_8).mark_line(color='green', point = True).encode(
    alt.X('iteration:N'),
    alt.Y('test:Q', scale=alt.Scale(zero=False)),
    tooltip = ['test']
)

c2 = alt.Chart(depth_9).mark_line(color='red', point = True).encode(
    alt.X('iteration:N'),
    alt.Y('test:Q', scale=alt.Scale(zero=False)),
    tooltip = ['test']
)

c3 = alt.Chart(depth_10).mark_line(color='blue', point = True).encode(
    alt.X('iteration:N'),
    alt.Y('test:Q', scale=alt.Scale(zero=False)),
    tooltip = ['test']
)

c4 = alt.Chart(depth_11).mark_line(color='orange', point = True).encode(
    alt.X('iteration:N'),
    alt.Y('test:Q', scale=alt.Scale(zero=False)),
    tooltip = ['test']
)

c5 = alt.Chart(depth_12).mark_line(color='black', point = True).encode(
    alt.X('iteration:N'),
    alt.Y('test:Q', scale=alt.Scale(zero=False)),
    tooltip = ['test']
)

c6 = alt.Chart(depth_13).mark_line(color='yellow', point = True).encode(
    alt.X('iteration:N'),
    alt.Y('test:Q', scale=alt.Scale(zero=False)),
    tooltip = ['test']
)

# %%
(c1 + c2 + c3 + c4 + c5 + c6).interactive()

# %%
reg = pd.read_csv('data/encoding_reg.csv')
normal = pd.read_csv('data/encoding_normal.csv')

# %%
c1 = alt.Chart(normal).mark_line(color='blue', point = True).encode(
    alt.X('iteration:N'),
    alt.Y('training:Q', scale=alt.Scale(zero=False)),
    tooltip = ['training']
)

c2 = alt.Chart(normal).mark_line(color='red', point = True).encode(
    alt.X('iteration:N'),
    alt.Y('test:Q', scale=alt.Scale(zero=False)),
    tooltip = ['test']
)

# %%
c3 = alt.Chart(reg).mark_line(color='blue', point = True).encode(
    alt.X('iteration:N'),
    alt.Y('training:Q', scale=alt.Scale(zero=False)),
    tooltip = ['training']
)

c4 = alt.Chart(reg).mark_line(color='red', point = True).encode(
    alt.X('iteration:N'),
    alt.Y('test:Q', scale=alt.Scale(zero=False)),
    tooltip = ['test']
)

# %%
(c1 + c2).interactive() & (c3 + c4).interactive()

# %%
c3 = alt.Chart(normal).mark_line(color='blue', point = True).encode(
    alt.X('iteration:N'),
    alt.Y('test:Q', scale=alt.Scale(zero=False)),
    tooltip = ['test']
)

c4 = alt.Chart(reg).mark_line(color='red', point = True).encode(
    alt.X('iteration:N'),
    alt.Y('test:Q', scale=alt.Scale(zero=False)),
    tooltip = ['test']
)

# %%
(c3 + c4).interactive()

# %%
{12: 33.675610,
 13: 35.245171,
 14: 36.195442,
 15: 35.658811,
 16: 34.918525,
 17: 34.392044,
 18: 34.684944,
 19: 36.144526,
 20: 37.951523,
 21: 40.815324,
 22: 46.257598,
 23: 55.966912
}

# %%
mose = pd.read_csv('data/mose.csv')
mose.head()
# Out:
#          date        volume      ruble
# 0  01.11.2015  723488266876  65.083095
# 1  01.10.2015  770901921962  63.126499
# 2  01.09.2015  611322339144  66.950360
# 3  01.08.2015  658019892165  65.355082
# 4  01.07.2015  633718833580  57.155767

# %%
mose['date'] = pd.to_datetime(mose['date'])

# %%
alt.Chart(mose).mark_line().encode(
    alt.X('date:N'),
    alt.Y('ruble:Q')
) & alt.Chart(mose).mark_line().encode(
    alt.X('date:N'),
    alt.Y('volume:Q')
)
